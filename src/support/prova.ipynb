# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from ProjectionBuilder import ProjectionBuilder

# %%
import sqlite3

# %%
df = pd.read_csv(r'C:\Users\TCXBQOI\OneDrive - Volkswagen AG\FairCOD\results\20240729_222921_360361\24.3_OLA_mapped.csv')

# %%
df.columns
# Out:
# Index(['Epic_ID', 'DPC', 'Epic_Name', 'CoD', 'Backlog',
#        'EconomicImpact_Income', 'EconomicImpact_CostsSaving',
#        'EconomicImpact_LossPrevention', 'Strategy_Value',
#        'UserExperience_FutureCustomerExperience_Value',
#        'PlatformUsage_FinalValue', 'Markets_Value',
#        'CustomerSatisfaction_Value', 'Critical_Event_value',
#        'Margin_to_deadline', 'Margin_to_deadline_value',
#        'WOWA_RankExponent_4_24.3', 'WOWA_RankExponent_4_24.3_scaled',
#        'WOWA_RankExponent_4_24.3_class', 'WOWA_RankExponent_4_24.3_fairCOD',
#        'CoD_class'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# Create the plot
fig, ax = plt.subplots(figsize=(10, 2))

# Plot the data points
ax.plot([0, 1], [0, 0], 'b-', linewidth=2)
ax.plot(df['WOWA_RankExponent_4_24.3'], np.zeros_like(df['WOWA_RankExponent_4_24.3']), 'ro', markersize=8)

# Set the y-axis limits to show only a small range around zero
ax.set_ylim(-0.5, 0.5)

# Remove y-axis ticks
ax.yaxis.set_ticks([])

# Set x-axis limits
#ax.set_xlim(-0.1, 1.1)

# Add a title
plt.title('Scores of LPM Epics of APP Backlog')

# Add x-axis label
plt.xlabel('Scores')

# Show the plot
plt.tight_layout()
plt.savefig(r'C:\Users\TCXBQOI\OneDrive - Volkswagen AG\FairCOD\results\Scores_24_3_APP.png', bbox_inches='tight', dpi=300)
plt.show()

# %%
# Create the plot
fig, ax = plt.subplots(figsize=(10, 2))

# Plot the data points
ax.plot([0, 1], [0, 0], 'b-', linewidth=2)
ax.plot(df['WOWA_RankExponent_4_24.3_scaled'], np.zeros_like(df['WOWA_RankExponent_4_24.3_scaled']), 'ro', markersize=8)

# Set the y-axis limits to show only a small range around zero
ax.set_ylim(-0.5, 0.5)

# Remove y-axis ticks
ax.yaxis.set_ticks([])

# Set x-axis limits
#ax.set_xlim(-0.1, 1.1)

# Add a title
plt.title('Scaled Scores of LPM Epics of APP Backlog')

# Add x-axis label
plt.xlabel('Scaled Scores')

# Show the plot
plt.tight_layout()
plt.savefig(r'C:\Users\TCXBQOI\OneDrive - Volkswagen AG\FairCOD\results\Scores_24_3_APP_scaled.png', bbox_inches='tight', dpi=300)
plt.show()

# %%
df_WS = pd.read_csv(r'C:\Users\TCXBQOI\OneDrive - Volkswagen AG\FairCOD\results\20240729_222921_360361\24.3_Websites_mapped.csv')

# %%
# Create the plot
fig, ax = plt.subplots(figsize=(10, 2))

# Plot the data points
ax.plot([0, 1], [0, 0], 'b-', linewidth=2)
ax.plot(df_WS['WOWA_RankExponent_4_24.3'], np.zeros_like(df_WS['WOWA_RankExponent_4_24.3']), 'ro', markersize=8)

# Set the y-axis limits to show only a small range around zero
ax.set_ylim(-0.5, 0.5)

# Remove y-axis ticks
ax.yaxis.set_ticks([])

# Set x-axis limits
#ax.set_xlim(-0.1, 1.1)

# Add a title
plt.title('Scores of LPM Epics of Websites Backlog')

# Add x-axis label
plt.xlabel('Scores')

# Show the plot
plt.tight_layout()
plt.savefig(r'C:\Users\TCXBQOI\OneDrive - Volkswagen AG\FairCOD\results\Scores_24_3_WS.png', bbox_inches='tight', dpi=300)

plt.show()

# %%
# Create the plot
fig, ax = plt.subplots(figsize=(10, 2))

# Plot the data points
ax.plot([0, 1], [0, 0], 'b-', linewidth=2)
ax.plot(df_WS['WOWA_RankExponent_4_24.3_scaled'], np.zeros_like(df_WS['WOWA_RankExponent_4_24.3_scaled']), 'ro', markersize=8)

# Set the y-axis limits to show only a small range around zero
ax.set_ylim(-0.5, 0.5)

# Remove y-axis ticks
ax.yaxis.set_ticks([])

# Set x-axis limits
#ax.set_xlim(-0.1, 1.1)

# Add a title
plt.title('Scores of LPM Epics of Websites Backlog')

# Add x-axis label
plt.xlabel('Scores')

# Show the plot
plt.tight_layout()
plt.savefig(r'C:\Users\TCXBQOI\OneDrive - Volkswagen AG\FairCOD\results\Scores_24_3_WS_scaled.png', bbox_inches='tight', dpi=300)
plt.show()

# %%
df_OVS = pd.read_csv(r'C:\Users\TCXBQOI\OneDrive - Volkswagen AG\FairCOD\results\20240729_222921_360361\24.3_Online Sales_mapped.csv')

# %%
# Create the plot
fig, ax = plt.subplots(figsize=(10, 2))

# Plot the data points
ax.plot([0, 1], [0, 0], 'b-', linewidth=2)
ax.plot(df_OVS['WOWA_RankExponent_4_24.3'], np.zeros_like(df_OVS['WOWA_RankExponent_4_24.3']), 'ro', markersize=8)

# Set the y-axis limits to show only a small range around zero
ax.set_ylim(-0.5, 0.5)

# Remove y-axis ticks
ax.yaxis.set_ticks([])

# Set x-axis limits
#ax.set_xlim(-0.1, 1.1)

# Add a title
plt.title('Scores of LPM Epics of Online Sales Backlog')

# Add x-axis label
plt.xlabel('Scores')

# Show the plot
plt.tight_layout()
plt.savefig(r'C:\Users\TCXBQOI\OneDrive - Volkswagen AG\FairCOD\results\Scores_24_3_OVS.png', bbox_inches='tight', dpi=300)
plt.show()

# %%
# Create the plot
fig, ax = plt.subplots(figsize=(10, 2))

# Plot the data points
ax.plot([0, 1], [0, 0], 'b-', linewidth=2)
ax.plot([0,1],[0,0], 'bo', markersize=8)

# Set the y-axis limits to show only a small range around zero
ax.set_ylim(-0.5, 0.5)

# Remove y-axis ticks
ax.yaxis.set_ticks([])

# Set x-axis limits
#ax.set_xlim(-0.1, 1.1)

# Add a title
plt.title('Scores of LPM Epics of Online Sales Backlog')

# Add x-axis label
plt.xlabel('Scores')

# Show the plot
plt.tight_layout()
#plt.savefig(r'C:\Users\TCXBQOI\OneDrive - Volkswagen AG\FairCOD\results\Scores_24_3_OVS_scaled.png', bbox_inches='tight', dpi=300)
plt.savefig(r'C:\Users\TCXBQOI\OneDrive - Volkswagen AG\FairCOD\results\mapping_space_empty.png')
plt.show()

# %%
mapping_Fib2Class = {
    1:1,
    2:2,
    3:3,
    5:4,
    8:5,
    13:6,
    21:7,
    40:8,
    100:9
}

# %%
backlog='Websites'

# %%
PB = ProjectionBuilder(df_WS['CoD'].map(mapping_Fib2Class), backlog=backlog)

# %%
PB.plot_projection_space(save_img=True,
                         save_img_path = r'C:\Users\TCXBQOI\OneDrive - Volkswagen AG\FairCOD\results')

# %%
df_WS[['Epic_Name', 'CoD']].sort_values('CoD')
# Out:
#                                             Epic_Name    CoD
# 28                                     CUPRA Glossary    1.0
# 29            Migration to Central Form Builder (AEM)    2.0
# 23  [AFTERSALES] Tool for check the next maintenan...    3.0
# 1                                        Web Searcher    3.0
# 20  Rate your experience survey integration in AEM...    3.0
# 25  Different delivery options selectable by the c...    3.0
# 26      Customer handover preferences in Private Area    3.0
# 27               (CONNECT) Services availability list    3.0
# 24                    Private Area complete re-design    3.0
# 17                           Promote CONNECT Services    5.0
# 15               Charging@web: Home charging features    5.0
# 0   NEW TEMPLATE FUNCTIONALITIES TO AMPLIFY THE CO...    5.0
# 8                             AI assistant in website    8.0
# 31       [AFTERSALES] Recall / Service Campaign Check    8.0
# ...

# %%
PB_app = ProjectionBuilder(df['CoD'].map(mapping_Fib2Class), backlog='APP')
PB_app.plot_projection_space(save_img=True,
                         save_img_path = r'C:\Users\TCXBQOI\OneDrive - Volkswagen AG\FairCOD\results')

# %%
PB_ovs = ProjectionBuilder(df_OVS['CoD'].map(mapping_Fib2Class), backlog='Online Sales')
PB_ovs.plot_projection_space(save_img=True,
                         save_img_path = r'C:\Users\TCXBQOI\OneDrive - Volkswagen AG\FairCOD\results')

# %%
from ProjectionBuilderV2 import ProjectionBuilder

# %%
PB_app = ProjectionBuilder(df=df, backlog='APP')
PB_app.plot_projection_space(save_img=True,
                         save_img_path = r'C:\Users\TCXBQOI\OneDrive - Volkswagen AG\FairCOD\results2')

# %%
PB_ovs = ProjectionBuilder(df=df_OVS, backlog='Online Sales')
PB_ovs.plot_projection_space(save_img=True,
                         save_img_path = r'C:\Users\TCXBQOI\OneDrive - Volkswagen AG\FairCOD\results2')

# %%
PB_ws = ProjectionBuilder(df=df_WS, backlog='Websites')
PB_ws.plot_projection_space(save_img=True,
                         save_img_path = r'C:\Users\TCXBQOI\OneDrive - Volkswagen AG\FairCOD\results2')
